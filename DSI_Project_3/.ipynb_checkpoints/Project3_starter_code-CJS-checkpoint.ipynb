# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %%
import pandas as pd

## Load the data into a DataFrame
df = pd.read_csv('assets/Iowa_Liquor_sales_sample_10pct.csv')

# %% [markdown]
# **Transform and clean data**
# - rename columns
# - adjust formats (date to datetime format, strings to numbers, etc.)
# - drop nan values
# - convert money columns from string to float

# %%
df.columns = [x.lower().replace(' ','_').replace('(', '').replace(')', '') for x in df.columns]
df["date"] = pd.to_datetime(df["date"], format="%m/%d/%Y")  # time into a datetime format
df = df.drop(df[df.zip_code == '712-2'].index)  # drop the rows with bad zip code data
df.dropna(inplace=True)  # drop rows that are annoying us with NaN values
df['store_number'] = df['store_number'].astype('int')  # convert from string to number
df['zip_code'] = df['zip_code'].astype('int') # convert from string to number

# %%
# convert money values from string to float
def convert_money(x):
    x = x.strip('$')
    return float(x)

df['sale_dollars'] = df['sale_dollars'].apply(convert_money)
df['state_bottle_cost'] = df['state_bottle_cost'].apply(convert_money)
df['state_bottle_retail'] = df['state_bottle_retail'].apply(convert_money)

# %%
df.head()
# Out:
#         date  store_number         city  zip_code  county_number      county  \
# 0 2015-11-04          3717       SUMNER     50674            9.0      Bremer
# 1 2016-03-02          2614    DAVENPORT     52807           82.0       Scott
# 2 2016-02-11          2106  CEDAR FALLS     50613            7.0  Black Hawk
# 3 2016-02-03          2501         AMES     50010           85.0       Story
# 4 2015-08-18          3654      BELMOND     50421           99.0      Wright
#
#     category              category_name  vendor_number  item_number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             item_description  bottle_volume_ml  state_bottle_cost  \
# 0  Mr. Boston Apricot Brandy               750               4.50
# 1                    Tin Cup               750              13.75
# 2                   Jim Beam              1000              12.59
# 3    1800 Ultimate Margarita              1750               9.50
# 4         Five O'clock Vodka              1750               7.20
#
#    state_bottle_retail  bottles_sold  sale_dollars  volume_sold_liters  \
# 0                 6.75            12         81.00                 9.0
# 1                20.63             2         41.26                 1.5
# 2                18.89            24        453.36                24.0
# 3                14.25             6         85.50                10.5
# 4                10.80            12        129.60                21.0
#
#    volume_sold_gallons
# 0                 2.38
# 1                 0.40
# 2                 6.34
# 3                 2.77
# 4                 5.55

# %% [markdown]
# **Standardize all the data we want to graph, into another dataframe**

# %%
from sklearn.preprocessing import StandardScaler
df_graph = df.sample(frac=0.001)   # create a small copy to standardize

cont_feats = ['bottle_volume_ml', 'volume_sold_liters', 'volume_sold_gallons', 'bottles_sold', 'sale_dollars']
df_graph[cont_feats] = StandardScaler().fit_transform(df_graph[cont_feats])

# %% [markdown]
# **Do some quick and dirty visualization comparisons**

# %%
# an excellent way to start analysis - get an overview with scatter matrix
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

a=scatter_matrix(df_graph[['store_number', 'county_number', 'category', 'item_number', \
                          'bottle_volume_ml']], alpha=0.2, figsize=(10, 10), diagonal='kde')

# %%
import seaborn as sns
sns.pairplot(df_graph[['volume_sold_liters', 'volume_sold_gallons', \
                          'zip_code','bottles_sold','vendor_number']],size=3)

# %% [markdown]
# **Conclusions from graphing**
# In general it doesn't appear that as represented strictly in the dataframe, that any meaningful data is correlated (though obviously further mixing and matching of features could be attempted).

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %% [markdown]
# #### Calculate the yearly liquor sales for each store

# %%
# create new dataframe with 2016 data removed
d_2015 = df[df['date'].dt.year == 2015]

# %%
s2015a = pd.DataFrame(data=d_2015.groupby(['item_description', 'bottle_volume_ml', 'state_bottle_retail']) \
                       ['bottles_sold'].count())

# %%
s2015a.head()
# Out:
#                                                           bottles_sold
# item_description    bottle_volume_ml state_bottle_retail
# 10 Cane Rum         750              18.75                           1
# 1792 Sweet Wheat HA 750              27.75                           4
# 1800 Anejo Tequila  750              29.25                          27
# 1800 Coconut        750              23.19                          27
# 1800 Peach          1750             14.25                          33

# %%
d_2015['quality'] = d_2015['state_bottle_retail'] / d_2015['bottle_volume_ml']
# Out:
# /Users/deepstructure/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
d_2015.sort_values(by= 'quality', ascending=False)
# Out:
#              date  store_number             city  zip_code  county_number  \
# 196351 2015-02-26          2663        URBANDALE     50322           77.0
# 255223 2015-06-30          3952       BETTENDORF     52722           82.0
# 90202  2015-11-09          3952       BETTENDORF     52722           82.0
# 160897 2015-09-08          2665           WAUKEE     50263           25.0
# 3011   2015-06-23          4070     BELLE PLAINE     52208            6.0
# 264679 2015-12-26          2633       DES MOINES     50320           77.0
# 262300 2015-07-28          2666           ANKENY     50023           77.0
# 244285 2015-07-29          3869       CORALVILLE     52241           52.0
# 218708 2015-05-04          2190       DES MOINES     50314           77.0
# 218271 2015-02-24          4042         GLENWOOD     51534           65.0
# 221185 2015-05-04          2538         WATERLOO     50702            7.0
# 63192  2015-05-04          3814  WEST DES MOINES     50266           25.0
# 179356 2015-03-30          2633       DES MOINES     50320           77.0
# 268414 2015-11-12          2616          CLINTON     52732           23.0
# 7879   2015-12-14          2248       DES MOINES     50312           77.0
# 218116 2015-12-16          3698  WEST DES MOINES     50266           77.0
# 20825  2015-12-26          2670       CORALVILLE     52241           52.0
# 85842  2015-11-16          4829       DES MOINES     50314           77.0
# 50748  2015-11-16          2512        IOWA CITY     52240           52.0
# 69756  2015-11-24          2633       DES MOINES     50320           77.0
# 260072 2015-12-29          2587         JOHNSTON     50131           77.0
# 182318 2015-01-12          3773     CEDAR RAPIDS     52401           57.0
# 190148 2015-04-20          4829       DES MOINES     50314           77.0
# 138040 2015-08-19          2502           ANKENY     50021           77.0
# 138620 2015-05-18          2560           MARION     52302           57.0
# 267673 2015-09-28          2590     CEDAR RAPIDS     52402           57.0
# 29715  2015-07-30          2515       MASON CITY     50401           17.0
# 187941 2015-12-18          4165           ANKENY     50023           77.0
# 46911  2015-03-18          3682           WESLEY     50483           55.0
# 111786 2015-04-14          2624          DUBUQUE     52002           31.0
# ...           ...           ...              ...       ...            ...
# 53271  2015-12-02          2625        DAVENPORT     52804           82.0
# 178475 2015-06-03          4481        IOWA CITY     52240           52.0
# 146604 2015-08-10          2190       DES MOINES     50314           77.0
# 133169 2015-01-05          3952       BETTENDORF     52722           82.0
# 203121 2015-02-04          3926        IOWA CITY     52240           52.0
# 104034 2015-09-30          2625        DAVENPORT     52804           82.0
# 185752 2015-10-08          2612            PERRY     50220           25.0
# 256112 2015-11-02          3385     CEDAR RAPIDS     52402           57.0
# 914    2015-04-07          4336           GEORGE     51237           60.0
# 269908 2015-12-15          4277          LE MARS     51031           75.0
# 52891  2015-08-17          4504        INDIANOLA     50125           91.0
# 11927  2015-08-05          2572      CEDAR FALLS     50613            7.0
# 51991  2015-10-13          2552     CEDAR RAPIDS     52404           57.0
# 11886  2015-09-14          2448        INDIANOLA     50125           91.0
# 105591 2015-07-21          2624          DUBUQUE     52002           31.0
# 95934  2015-09-04          2662        MUSCATINE     52761           70.0
# 33764  2015-10-19          2605     CEDAR RAPIDS     52402           57.0
# 205292 2015-10-22          2806          CLINTON     52732           23.0
# 47486  2015-10-12          2538         WATERLOO     50702            7.0
# 67141  2015-09-23          5180          OELWEIN     50662           33.0
# 49951  2015-08-18          3621          SHELDON     51201           71.0
# 75071  2015-08-19          3584          OELWEIN     50662           33.0
# 49097  2015-07-22          4896    HARPERS FERRY     52146            3.0
# 245116 2015-07-22          3650         HOLSTEIN     51025           47.0
# 252534 2015-07-08          3723            ONAWA     51040           67.0
# 96574  2015-10-21          3990        OSKALOOSA     52577           62.0
# 262961 2015-09-08          2552     CEDAR RAPIDS     52404           57.0
# 227972 2015-07-08          3773     CEDAR RAPIDS     52401           57.0
# 50544  2015-09-08          2624          DUBUQUE     52002           31.0
# 189270 2015-07-29          4631      CEDAR FALLS     50613            7.0
#
#              county   category                       category_name  \
# 196351         Polk  1012200.0                     SCOTCH WHISKIES
# 255223        Scott  1012200.0                     SCOTCH WHISKIES
# 90202         Scott  1042100.0                   IMPORTED DRY GINS
# 160897       Dallas  1011200.0           STRAIGHT BOURBON WHISKIES
# 3011         Benton  1052010.0             IMPORTED GRAPE BRANDIES
# 264679         Polk  1012300.0                      IRISH WHISKIES
# 262300         Polk  1012200.0                     SCOTCH WHISKIES
# 244285      Johnson  1012200.0                     SCOTCH WHISKIES
# 218708         Polk  1012300.0                      IRISH WHISKIES
# 218271        Mills  1012200.0                     SCOTCH WHISKIES
# 221185   Black Hawk  1012300.0                      IRISH WHISKIES
# 63192        Dallas  1012300.0                      IRISH WHISKIES
# 179356         Polk  1052010.0             IMPORTED GRAPE BRANDIES
# 268414      Clinton  1012210.0                  SINGLE MALT SCOTCH
# 7879           Polk  1012210.0                  SINGLE MALT SCOTCH
# 218116         Polk  1012210.0                  SINGLE MALT SCOTCH
# 20825       Johnson  1012210.0                  SINGLE MALT SCOTCH
# 85842          Polk  1012210.0                  SINGLE MALT SCOTCH
# 50748       Johnson  1012210.0                  SINGLE MALT SCOTCH
# 69756          Polk  1012210.0                  SINGLE MALT SCOTCH
# 260072         Polk  1012210.0                  SINGLE MALT SCOTCH
# 182318         Linn  1012200.0                     SCOTCH WHISKIES
# 190148         Polk  1012200.0                     SCOTCH WHISKIES
# 138040         Polk  1012200.0                     SCOTCH WHISKIES
# 138620         Linn  1012200.0                     SCOTCH WHISKIES
# 267673         Linn  1012200.0                     SCOTCH WHISKIES
# 29715   Cerro Gordo  1012200.0                     SCOTCH WHISKIES
# 187941         Polk  1012200.0                     SCOTCH WHISKIES
# 46911       Kossuth  1012200.0                     SCOTCH WHISKIES
# 111786      Dubuque  1012200.0                     SCOTCH WHISKIES
# ...             ...        ...                                 ...
# 53271         Scott  1081400.0                          TRIPLE SEC
# 178475      Johnson  1081400.0                          TRIPLE SEC
# 146604         Polk  1081400.0                          TRIPLE SEC
# 133169        Scott  1081400.0                          TRIPLE SEC
# 203121      Johnson  1081400.0                          TRIPLE SEC
# 104034        Scott  1081400.0                          TRIPLE SEC
# 185752       Dallas  1081400.0                          TRIPLE SEC
# 256112         Linn  1081400.0                          TRIPLE SEC
# 914            Lyon  1081400.0                          TRIPLE SEC
# 269908     Plymouth  1081400.0                          TRIPLE SEC
# 52891        Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 11927    Black Hawk  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 51991          Linn  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 11886        Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 105591      Dubuque  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 95934     Muscatine  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 33764          Linn  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 205292      Clinton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 47486    Black Hawk  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 67141       Fayette  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 49951       O'Brien  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 75071       Fayette  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 49097     Allamakee  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 245116          Ida  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 252534       Monona  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 96574       Mahaska  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 262961         Linn  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 227972         Linn  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 50544       Dubuque  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 189270   Black Hawk  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
#
#         vendor_number  item_number  \
# 196351            260       995381
# 255223            260       994764
# 90202              35       902282
# 160897             65       919471
# 3011              420       990482
# 264679            260       905460
# 262300            305       995507
# 244285            305       995507
# 218708            370       915863
# 218271            260       905405
# 221185            370       915863
# 63192             370       915863
# 179356            446       901395
# 268414            305         5516
# 7879              305         5516
# 218116            305         5516
# 20825             305         5516
# 85842             305         5516
# 50748             305         5516
# 69756             305         5516
# 260072            305         5516
# 182318            260       900562
# 190148            260         5329
# 138040            260         5329
# 138620            260         5329
# 267673            260         5329
# 29715             260         5329
# 187941            260         5329
# 46911             260         5329
# 111786            260         5329
# ...               ...          ...
# 53271              55        86390
# 178475             55        86390
# 146604             55        86390
# 133169             55        86390
# 203121             55        86390
# 104034             55        86390
# 185752             55        86390
# 256112             55        86390
# 914                55        86390
# 269908             55        86390
# 52891             421        64985
# 11927             421        64985
# 51991             421        64985
# 11886             421        64985
# 105591            421        64985
# 95934             421        64985
# 33764             421        64985
# 205292            421        64985
# 47486             421        64985
# 67141             421        64985
# 49951             421        64985
# 75071             421        64985
# 49097             421        64985
# 245116            421        64985
# 252534            421        64985
# 96574             421        64985
# 262961            421        64985
# 227972            421        64985
# 50544             421        64985
# 189270            421        64985
#
#                                        item_description  bottle_volume_ml  \
# 196351  Johnnie Walker Private Collection 2015 Fruit HA               750
# 255223                                 Caol Ila 30YR HA               750
# 90202                         Bombay Sapphire Gin Minis                50
# 160897                                Maker's Mark Mini                50
# 3011                    Hennessy 250 Collector Blend HA              1000
# 264679                                 Mortlach 18YR HA               750
# 262300                            Macallan Rare Cask HA               750
# 244285                            Macallan Rare Cask HA               750
# 218708                                Redbreast 21yr HA               750
# 218271           Johnnie Walker Blue Year of the Ram HA               750
# 221185                                Redbreast 21yr HA               750
# 63192                                 Redbreast 21yr HA               750
# 179356                              Calvados Morin 1973               750
# 268414                 Macallan 18yr Single Malt Scotch               750
# 7879                   Macallan 18yr Single Malt Scotch               750
# 218116                 Macallan 18yr Single Malt Scotch               750
# 20825                  Macallan 18yr Single Malt Scotch               750
# 85842                  Macallan 18yr Single Malt Scotch               750
# 50748                  Macallan 18yr Single Malt Scotch               750
# 69756                  Macallan 18yr Single Malt Scotch               750
# 260072                 Macallan 18yr Single Malt Scotch               750
# 182318               Johnnie Walker Blue Gift Bottle HA               750
# 190148                              Johnnie Walker Blue               750
# 138040                              Johnnie Walker Blue               750
# 138620                              Johnnie Walker Blue               750
# 267673                              Johnnie Walker Blue               750
# 29715                               Johnnie Walker Blue               750
# 187941                              Johnnie Walker Blue               750
# 46911                               Johnnie Walker Blue               750
# 111786                              Johnnie Walker Blue               750
# ...                                                 ...               ...
# 53271                              Montezuma Triple Sec              1000
# 178475                             Montezuma Triple Sec              1000
# 146604                             Montezuma Triple Sec              1000
# 133169                             Montezuma Triple Sec              1000
# 203121                             Montezuma Triple Sec              1000
# 104034                             Montezuma Triple Sec              1000
# 185752                             Montezuma Triple Sec              1000
# 256112                             Montezuma Triple Sec              1000
# 914                                Montezuma Triple Sec              1000
# 269908                             Montezuma Triple Sec              1000
# 52891                 French Kiss Tropical Liqueur Mini              3000
# 11927                 French Kiss Tropical Liqueur Mini              3000
# 51991                 French Kiss Tropical Liqueur Mini              3000
# 11886                 French Kiss Tropical Liqueur Mini              3000
# 105591                French Kiss Tropical Liqueur Mini              3000
# 95934                 French Kiss Tropical Liqueur Mini              3000
# 33764                 French Kiss Tropical Liqueur Mini              3000
# 205292                French Kiss Tropical Liqueur Mini              3000
# 47486                 French Kiss Tropical Liqueur Mini              3000
# 67141                 French Kiss Tropical Liqueur Mini              3000
# 49951                 French Kiss Tropical Liqueur Mini              3000
# 75071                 French Kiss Tropical Liqueur Mini              3000
# 49097                 French Kiss Tropical Liqueur Mini              3000
# 245116                French Kiss Tropical Liqueur Mini              3000
# 252534                French Kiss Tropical Liqueur Mini              3000
# 96574                 French Kiss Tropical Liqueur Mini              3000
# 262961                French Kiss Tropical Liqueur Mini              3000
# 227972                French Kiss Tropical Liqueur Mini              3000
# 50544                 French Kiss Tropical Liqueur Mini              3000
# 189270                French Kiss Tropical Liqueur Mini              3000
#
#         state_bottle_cost  state_bottle_retail  bottles_sold  sale_dollars  \
# 196351             425.00               637.50             1        637.50
# 255223             349.99               524.99             1        524.99
# 90202               16.00                24.00            20        480.00
# 160897              15.72                23.58            10        235.80
# 3011               299.99               449.99             1        449.99
# 264679             168.00               252.00             1        252.00
# 262300             150.38               225.57             1        225.57
# 244285             150.38               225.57             2        451.14
# 218708             149.99               224.99             3        674.97
# 218271             149.99               224.99             2        449.98
# 221185             149.99               224.99             1        224.99
# 63192              149.99               224.99             2        449.98
# 179356             139.00               208.50             1        208.50
# 268414             135.25               202.88             1        202.88
# 7879               135.25               202.88             3        608.64
# 218116             135.25               202.88             3        608.64
# 20825              135.25               202.88             1        202.88
# 85842              135.25               202.88            12       2434.56
# 50748              135.25               202.88             2        405.76
# 69756              135.25               202.88            12       2434.56
# 260072             135.25               202.88             1        202.88
# 182318             134.99               202.49             1        202.49
# 190148             130.00               195.00             2        390.00
# 138040             130.00               195.00             1        195.00
# 138620             130.00               195.00             2        390.00
# 267673             130.00               195.00             1        195.00
# 29715              130.00               195.00             1        195.00
# 187941             130.00               195.00             1        195.00
# 46911              130.00               195.00             1        195.00
# 111786             130.00               195.00             1        195.00
# ...                   ...                  ...           ...           ...
# 53271                2.13                 3.20            12         38.40
# 178475               2.13                 3.20            36        115.20
# 146604               2.13                 3.20             3          9.60
# 133169               2.13                 3.20            36        115.20
# 203121               2.13                 3.20            24         76.80
# 104034               2.13                 3.20            12         38.40
# 185752               2.13                 3.20             3          9.60
# 256112               2.13                 3.20           192        614.40
# 914                  2.13                 3.20             1          3.20
# 269908               2.13                 3.20            12         38.40
# 52891                5.52                 8.28             3         24.84
# 11927                5.52                 8.28             1          8.28
# 51991                5.52                 8.28             4         33.12
# 11886                5.52                 8.28             1          8.28
# 105591               5.52                 8.28             4         33.12
# 95934                5.52                 8.28             4         33.12
# 33764                5.52                 8.28             1          8.28
# 205292               5.52                 8.28             1          8.28
# 47486                5.52                 8.28             1          8.28
# 67141                5.52                 8.28             1          8.28
# 49951                5.52                 8.28             4         33.12
# 75071                5.52                 8.28             1          8.28
# 49097                5.52                 8.28             1          8.28
# 245116               5.52                 8.28             1          8.28
# 252534               5.52                 8.28             1          8.28
# 96574                5.52                 8.28             4         33.12
# 262961               5.52                 8.28             4         33.12
# 227972               5.52                 8.28             1          8.28
# 50544                5.52                 8.28             4         33.12
# 189270               5.52                 8.28             1          8.28
#
#         volume_sold_liters  volume_sold_gallons   quality
# 196351                0.75                 0.20  0.850000
# 255223                0.75                 0.20  0.699987
# 90202                 1.00                 0.26  0.480000
# 160897                0.50                 0.13  0.471600
# 3011                  1.00                 0.26  0.449990
# 264679                0.75                 0.20  0.336000
# 262300                0.75                 0.20  0.300760
# 244285                1.50                 0.40  0.300760
# 218708                2.25                 0.59  0.299987
# 218271                1.50                 0.40  0.299987
# 221185                0.75                 0.20  0.299987
# 63192                 1.50                 0.40  0.299987
# 179356                0.75                 0.20  0.278000
# 268414                0.75                 0.20  0.270507
# 7879                  2.25                 0.59  0.270507
# 218116                2.25                 0.59  0.270507
# 20825                 0.75                 0.20  0.270507
# 85842                 9.00                 2.38  0.270507
# 50748                 1.50                 0.40  0.270507
# 69756                 9.00                 2.38  0.270507
# 260072                0.75                 0.20  0.270507
# 182318                0.75                 0.20  0.269987
# 190148                1.50                 0.40  0.260000
# 138040                0.75                 0.20  0.260000
# 138620                1.50                 0.40  0.260000
# 267673                0.75                 0.20  0.260000
# 29715                 0.75                 0.20  0.260000
# 187941                0.75                 0.20  0.260000
# 46911                 0.75                 0.20  0.260000
# 111786                0.75                 0.20  0.260000
# ...                    ...                  ...       ...
# 53271                12.00                 3.17  0.003200
# 178475               36.00                 9.51  0.003200
# 146604                3.00                 0.79  0.003200
# 133169               36.00                 9.51  0.003200
# 203121               24.00                 6.34  0.003200
# 104034               12.00                 3.17  0.003200
# 185752                3.00                 0.79  0.003200
# 256112              192.00                50.72  0.003200
# 914                   1.00                 0.26  0.003200
# 269908               12.00                 3.17  0.003200
# 52891                 9.00                 2.38  0.002760
# 11927                 3.00                 0.79  0.002760
# 51991                12.00                 3.17  0.002760
# 11886                 3.00                 0.79  0.002760
# 105591               12.00                 3.17  0.002760
# 95934                12.00                 3.17  0.002760
# 33764                 3.00                 0.79  0.002760
# 205292                3.00                 0.79  0.002760
# 47486                 3.00                 0.79  0.002760
# 67141                 3.00                 0.79  0.002760
# 49951                12.00                 3.17  0.002760
# 75071                 3.00                 0.79  0.002760
# 49097                 3.00                 0.79  0.002760
# 245116                3.00                 0.79  0.002760
# 252534                3.00                 0.79  0.002760
# 96574                12.00                 3.17  0.002760
# 262961               12.00                 3.17  0.002760
# 227972                3.00                 0.79  0.002760
# 50544                12.00                 3.17  0.002760
# 189270                3.00                 0.79  0.002760
#
# [218163 rows x 19 columns]

# %%
d_2015_Q1 = d_2015[(d_2015['date'].dt.month <= 3)]

# %%
s2015 = pd.DataFrame(data=d_2015.groupby(['store_number', 'zip_code', 'county', 'city']) \
                       ['bottles_sold', 'volume_sold_liters', 'sale_dollars'].sum())

# %%
s2015_Q1 = pd.DataFrame(data=d_2015_Q1.groupby(['store_number', 'zip_code', 'county', 'city']) \
                       ['bottles_sold', 'volume_sold_liters', 'sale_dollars'].sum())

# %%
s2015.reset_index(level=['store_number', 'zip_code', 'county', 'city'], inplace=True)
s2015_Q1.reset_index(level=['store_number', 'zip_code', 'county', 'city'], inplace=True)

# %%
s2015.rename(columns={'sale_dollars': 'year_sales'}, inplace=True)
s2015_Q1.rename(columns={'sale_dollars': '1st_quarter_sales'}, inplace=True)

# %%
s2015.insert(6, 'Q1_sales',  s2015_Q1['1st_quarter_sales'])

# %%
s2015['average_btl_price'] = s2015['year_sales'] / s2015['bottles_sold']

# %%
s2015.head(1)
# Out:
#    store_number  zip_code      county         city  bottles_sold  \
# 0          2106     50613  Black Hawk  CEDAR FALLS         10355
#
#    volume_sold_liters  Q1_sales  year_sales  average_btl_price
# 0             9719.85  39287.29    146038.7          14.103206

# %%
# same for 2016 (data only contains Q1 results)
d_2016 = df[df['date'].dt.year == 2016]
s2016 = pd.DataFrame(data=d_2016.groupby(['store_number', 'zip_code', 'county', 'city']) \
                       ['bottles_sold', 'volume_sold_liters', 'sale_dollars'].sum())
s2016.reset_index(level=['store_number', 'zip_code', 'county', 'city'], inplace=True)
s2016.rename(columns={'sale_dollars': 'Q1_sales'}, inplace=True)

# %%
s2016['average_btl_price'] = s2016['Q1_sales'] / s2016['bottles_sold']

# %%
s2016.head(1)
# Out:
#    store_number  zip_code      county         city  bottles_sold  \
# 0          2106     50613  Black Hawk  CEDAR FALLS          2218
#
#    volume_sold_liters  Q1_sales  average_btl_price
# 0             2116.25  30478.75          13.741546

# %%
# %matplotlib inline
import numpy as np

xs = s2015.Q1_sales.values
ys = s2015.year_sales.values

def beta(xs, ys):
    numerator = 0.
    denominator = 0.
    x_mean = np.mean(xs)
    y_mean = np.mean(ys)
    for x, y in zip(xs, ys):
        numerator += (x - x_mean) * (y - y_mean)
        denominator += (x - x_mean) * (x - x_mean)
    return numerator / denominator

def alpha(xs, ys):
    b = beta(xs, ys)
    a = np.mean(ys) - b * np.mean(xs)
    return a

# Plotting
from matplotlib import pyplot as plt

def predict(xs, ys):
    a = alpha(xs, ys)
    b = beta(xs, ys)
    yhats = [a + b * x for x in xs]
    return yhats

ps = predict(xs, ys)

# The raw data
plt.scatter(xs, ys)
# The best fit line
plt.plot(xs, ps)
plt.show()

# %% [markdown]
# #### Use the data from 2015 to make a linear model using as many variables as you find useful to predict the yearly sales of each store.
# - You must use the sales from Jan to March per store as one of your variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import seaborn as sns

from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import statsmodels.formula.api as smf

pd.set_option('display.notebook_repr_html', False)
# %matplotlib inline
plt.style.use('seaborn-white')

# %%
est = smf.ols('year_sales ~ Q1_sales', s2015).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     464.9
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           5.35e-88
# Time:                        08:21:53   Log-Likelihood:                -15283.
# No. Observations:                1260   AIC:                         3.057e+04
# Df Residuals:                    1258   BIC:                         3.058e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.024e+04   1371.220      7.471      0.000      7553.936  1.29e+04
# Q1_sales       2.3558      0.109     21.561      0.000         2.141     2.570
# ==============================================================================
# Omnibus:                     1767.115   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1080126.914
# Skew:                           7.443   Prob(JB):                         0.00
# Kurtosis:                     145.661   Cond. No.                     1.36e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
est = smf.ols('year_sales ~ average_btl_price', s2015).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     86.89
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           4.43e-20
# Time:                        08:28:09   Log-Likelihood:                -16770.
# No. Observations:                1372   AIC:                         3.354e+04
# Df Residuals:                    1370   BIC:                         3.356e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.853e+04   4418.240     -4.194      0.000     -2.72e+04 -9861.355
# average_btl_price  3335.1621    357.785      9.322      0.000      2633.295  4037.029
# ==============================================================================
# Omnibus:                     2285.624   Durbin-Watson:                   1.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1779764.783
# Skew:                          10.669   Prob(JB):                         0.00
# Kurtosis:                     178.150   Cond. No.                         41.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.cross_validation import KFold
import patsy
import statsmodels.api as sm

kf = KFold(len(s2015), n_folds=10)
kf
# Out:
# sklearn.cross_validation.KFold(n=1372, n_folds=10, shuffle=False, random_state=None)

# %%
for train_index, test_index in kf:
    train_data_df = s2015.iloc[train_index]
    y, X = patsy.dmatrices('year_sales ~ Q1_sales', data=train_data_df, return_type='dataframe')
    model = sm.OLS(y, X)
    results = model.fit()
    print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.57
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):            0.00118
# Time:                        09:10:22   Log-Likelihood:                -13460.
# No. Observations:                1122   AIC:                         2.692e+04
# Df Residuals:                    1120   BIC:                         2.693e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.349e+04   1254.040     10.756      0.000       1.1e+04  1.59e+04
# Q1_sales       0.4201      0.129      3.252      0.001         0.167     0.674
# ==============================================================================
# Omnibus:                     2051.830   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2499297.971
# Skew:                          12.674   Prob(JB):                         0.00
# Kurtosis:                     232.823   Cond. No.                     1.04e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     589.3
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):          6.21e-105
# Time:                        09:10:22   Log-Likelihood:                -13517.
# No. Observations:                1122   AIC:                         2.704e+04
# Df Residuals:                    1120   BIC:                         2.705e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   8099.5299   1328.246      6.098      0.000      5493.400  1.07e+04
# Q1_sales       2.6641      0.110     24.275      0.000         2.449     2.879
# ==============================================================================
# Omnibus:                     1680.279   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2086924.537
# Skew:                           8.139   Prob(JB):                         0.00
# Kurtosis:                     213.654   Cond. No.                     1.30e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     526.2
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           8.73e-96
# Time:                        09:10:22   Log-Likelihood:                -13605.
# No. Observations:                1123   AIC:                         2.721e+04
# Df Residuals:                    1121   BIC:                         2.722e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   8887.4169   1422.135      6.249      0.000      6097.071  1.17e+04
# Q1_sales       2.5872      0.113     22.939      0.000         2.366     2.809
# ==============================================================================
# Omnibus:                     1604.727   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1331202.727
# Skew:                           7.535   Prob(JB):                         0.00
# Kurtosis:                     170.996   Cond. No.                     1.36e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     426.0
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.80e-80
# Time:                        09:10:22   Log-Likelihood:                -13674.
# No. Observations:                1123   AIC:                         2.735e+04
# Df Residuals:                    1121   BIC:                         2.736e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.045e+04   1519.693      6.878      0.000      7470.344  1.34e+04
# Q1_sales       2.3832      0.115     20.639      0.000         2.157     2.610
# ==============================================================================
# Omnibus:                     1542.521   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           825290.950
# Skew:                           7.126   Prob(JB):                         0.00
# Kurtosis:                     135.040   Cond. No.                     1.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     413.4
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.74e-78
# Time:                        09:10:22   Log-Likelihood:                -13678.
# No. Observations:                1123   AIC:                         2.736e+04
# Df Residuals:                    1121   BIC:                         2.737e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.098e+04   1531.688      7.167      0.000      7971.643   1.4e+04
# Q1_sales       2.3546      0.116     20.333      0.000         2.127     2.582
# ==============================================================================
# Omnibus:                     1540.634   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           800710.570
# Skew:                           7.121   Prob(JB):                         0.00
# Kurtosis:                     133.036   Cond. No.                     1.44e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     403.6
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           6.34e-77
# Time:                        09:10:23   Log-Likelihood:                -13682.
# No. Observations:                1123   AIC:                         2.737e+04
# Df Residuals:                    1121   BIC:                         2.738e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.134e+04   1541.688      7.354      0.000      8312.903  1.44e+04
# Q1_sales       2.3336      0.116     20.091      0.000         2.106     2.561
# ==============================================================================
# Omnibus:                     1537.089   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           776030.575
# Skew:                           7.100   Prob(JB):                         0.00
# Kurtosis:                     130.997   Cond. No.                     1.45e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     413.4
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.79e-78
# Time:                        09:10:23   Log-Likelihood:                -13677.
# No. Observations:                1123   AIC:                         2.736e+04
# Df Residuals:                    1121   BIC:                         2.737e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.106e+04   1531.753      7.218      0.000      8051.264  1.41e+04
# Q1_sales       2.3499      0.116     20.331      0.000         2.123     2.577
# ==============================================================================
# Omnibus:                     1543.704   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           807512.773
# Skew:                           7.147   Prob(JB):                         0.00
# Kurtosis:                     133.588   Cond. No.                     1.44e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     922.2
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):          2.66e-148
# Time:                        09:10:23   Log-Likelihood:                -13385.
# No. Observations:                1123   AIC:                         2.677e+04
# Df Residuals:                    1121   BIC:                         2.678e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   7005.4317   1202.707      5.825      0.000      4645.622  9365.241
# Q1_sales       3.0957      0.102     30.368      0.000         2.896     3.296
# ==============================================================================
# Omnibus:                      913.602   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           116634.303
# Skew:                           3.005   Prob(JB):                         0.00
# Kurtosis:                      52.563   Cond. No.                     1.31e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     408.4
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.12e-77
# Time:                        09:10:23   Log-Likelihood:                -13681.
# No. Observations:                1123   AIC:                         2.737e+04
# Df Residuals:                    1121   BIC:                         2.738e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.116e+04   1537.314      7.261      0.000      8145.655  1.42e+04
# Q1_sales       2.3428      0.116     20.208      0.000         2.115     2.570
# ==============================================================================
# Omnibus:                     1538.124   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           783935.771
# Skew:                           7.106   Prob(JB):                         0.00
# Kurtosis:                     131.654   Cond. No.                     1.44e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     455.6
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           2.81e-86
# Time:                        09:10:23   Log-Likelihood:                -14991.
# No. Observations:                1235   AIC:                         2.999e+04
# Df Residuals:                    1233   BIC:                         3.000e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.046e+04   1397.652      7.482      0.000      7714.991  1.32e+04
# Q1_sales       2.3586      0.111     21.345      0.000         2.142     2.575
# ==============================================================================
# Omnibus:                     1723.784   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1023538.479
# Skew:                           7.372   Prob(JB):                         0.00
# Kurtosis:                     143.261   Cond. No.                     1.37e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
for train_index, test_index in kf:
    train_data_df = s2015.iloc[train_index]
    y, X = patsy.dmatrices('year_sales ~ average_btl_price', data=train_data_df, return_type='dataframe')
    model = sm.OLS(y, X)
    results = model.fit()
    print results.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     64.86
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.88e-15
# Time:                        09:10:10   Log-Likelihood:                -14739.
# No. Observations:                1234   AIC:                         2.948e+04
# Df Residuals:                    1232   BIC:                         2.949e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.145e+04   3387.730     -3.380      0.001     -1.81e+04 -4805.567
# average_btl_price  2238.7530    277.976      8.054      0.000      1693.394  2784.113
# ==============================================================================
# Omnibus:                     2255.617   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3032666.768
# Skew:                          12.704   Prob(JB):                         0.00
# Kurtosis:                     244.530   Cond. No.                         39.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     66.93
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           6.93e-16
# Time:                        09:10:10   Log-Likelihood:                -15050.
# No. Observations:                1234   AIC:                         3.010e+04
# Df Residuals:                    1232   BIC:                         3.011e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.509e+04   4399.007     -3.431      0.001     -2.37e+04 -6463.536
# average_btl_price  2963.0625    362.174      8.181      0.000      2252.517  3673.608
# ==============================================================================
# Omnibus:                     2201.069   Durbin-Watson:                   1.699
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2392270.174
# Skew:                          12.132   Prob(JB):                         0.00
# Kurtosis:                     217.332   Cond. No.                         39.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     73.21
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           3.41e-17
# Time:                        09:10:10   Log-Likelihood:                -15118.
# No. Observations:                1235   AIC:                         3.024e+04
# Df Residuals:                    1233   BIC:                         3.025e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.838e+04   4713.061     -3.899      0.000     -2.76e+04 -9130.500
# average_btl_price  3298.8262    385.541      8.556      0.000      2542.438  4055.215
# ==============================================================================
# Omnibus:                     2094.548   Durbin-Watson:                   1.621
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1697133.434
# Skew:                          10.992   Prob(JB):                         0.00
# Kurtosis:                     183.270   Cond. No.                         40.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     85.28
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.09e-19
# Time:                        09:10:10   Log-Likelihood:                -15150.
# No. Observations:                1235   AIC:                         3.030e+04
# Df Residuals:                    1233   BIC:                         3.031e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept          -2.05e+04   4760.906     -4.306      0.000     -2.98e+04 -1.12e+04
# average_btl_price  3590.3532    388.780      9.235      0.000      2827.609  4353.097
# ==============================================================================
# Omnibus:                     2020.622   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1362931.804
# Skew:                          10.254   Prob(JB):                         0.00
# Kurtosis:                     164.448   Cond. No.                         40.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     78.41
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           2.85e-18
# Time:                        09:10:10   Log-Likelihood:                -15152.
# No. Observations:                1235   AIC:                         3.031e+04
# Df Residuals:                    1233   BIC:                         3.032e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.834e+04   4787.549     -3.830      0.000     -2.77e+04 -8944.818
# average_btl_price  3417.2479    385.909      8.855      0.000      2660.137  4174.359
# ==============================================================================
# Omnibus:                     2018.318   Durbin-Watson:                   1.663
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1347217.745
# Skew:                          10.234   Prob(JB):                         0.00
# Kurtosis:                     163.505   Cond. No.                         40.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     71.78
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           6.78e-17
# Time:                        09:10:10   Log-Likelihood:                -15156.
# No. Observations:                1235   AIC:                         3.032e+04
# Df Residuals:                    1233   BIC:                         3.033e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.709e+04   4893.931     -3.492      0.000     -2.67e+04 -7487.667
# average_btl_price  3295.7883    389.018      8.472      0.000      2532.578  4058.999
# ==============================================================================
# Omnibus:                     2013.112   Durbin-Watson:                   1.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1321918.599
# Skew:                          10.185   Prob(JB):                         0.00
# Kurtosis:                     161.979   Cond. No.                         42.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     79.37
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.81e-18
# Time:                        09:10:10   Log-Likelihood:                -15151.
# No. Observations:                1235   AIC:                         3.031e+04
# Df Residuals:                    1233   BIC:                         3.032e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.967e+04   4918.769     -3.999      0.000     -2.93e+04    -1e+04
# average_btl_price  3525.4959    395.731      8.909      0.000      2749.116  4301.876
# ==============================================================================
# Omnibus:                     2020.847   Durbin-Watson:                   1.671
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1357992.668
# Skew:                          10.258   Prob(JB):                         0.00
# Kurtosis:                     164.150   Cond. No.                         42.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     87.14
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           4.56e-20
# Time:                        09:10:10   Log-Likelihood:                -15007.
# No. Observations:                1235   AIC:                         3.002e+04
# Df Residuals:                    1233   BIC:                         3.003e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.691e+04   4324.759     -3.910      0.000     -2.54e+04 -8423.382
# average_btl_price  3235.1689    346.578      9.335      0.000      2555.222  3915.116
# ==============================================================================
# Omnibus:                     1982.638   Durbin-Watson:                   1.547
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1516437.504
# Skew:                           9.774   Prob(JB):                         0.00
# Kurtosis:                     173.549   Cond. No.                         41.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     100.8
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           7.56e-23
# Time:                        09:10:10   Log-Likelihood:                -15143.
# No. Observations:                1235   AIC:                         3.029e+04
# Df Residuals:                    1233   BIC:                         3.030e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -3.003e+04   5405.350     -5.556      0.000     -4.06e+04 -1.94e+04
# average_btl_price  4382.4945    436.565     10.039      0.000      3526.003  5238.986
# ==============================================================================
# Omnibus:                     2026.672   Durbin-Watson:                   1.665
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1373474.639
# Skew:                          10.318   Prob(JB):                         0.00
# Kurtosis:                     165.065   Cond. No.                         46.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             year_sales   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     79.30
# Date:                Fri, 23 Sep 2016   Prob (F-statistic):           1.87e-18
# Time:                        09:10:10   Log-Likelihood:                -15146.
# No. Observations:                1235   AIC:                         3.030e+04
# Df Residuals:                    1233   BIC:                         3.031e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Intercept         -1.988e+04   4930.368     -4.031      0.000     -2.95e+04 -1.02e+04
# average_btl_price  3540.2441    397.553      8.905      0.000      2760.288  4320.200
# ==============================================================================
# Omnibus:                     2030.091   Durbin-Watson:                   1.663
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1396466.056
# Skew:                          10.348   Prob(JB):                         0.00
# Kurtosis:                     166.430   Cond. No.                         42.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Conclusions
# - The Q1 numbers were much better predictors than the average bottle price - no surprise there.
# - I was surprised by the outliers on the Q1 predictors - there was one very low Adj.R(sq) score (0.008), and a high score (0.451). The rest all seemed clustered together in the high .2xx range.

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
from sklearn import linear_model

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.
